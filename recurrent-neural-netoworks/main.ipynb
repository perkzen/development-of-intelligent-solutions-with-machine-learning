# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, GRU, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('data/mbajk.csv')
df.head()
# Out:
#                         date  temperature  relative_humidity  dew_point  \
# 0  2023-07-30 12:12:58+00:00         24.1                 69       18.1
# 1  2023-09-11 20:14:06+00:00         19.2                 85       16.6
# 2  2023-07-09 05:12:32+00:00          NaN                 92       16.2
# 3  2023-07-21 12:37:13+00:00          NaN                 64       17.2
# 4  2023-07-03 17:01:20+00:00          NaN                 80       17.3
#
#    apparent_temperature  precipitation_probability  rain  surface_pressure  \
# 0                  27.5                       27.0   0.0             981.3
# 1                  20.9                        0.0   0.0             981.7
# 2                  19.2                        0.0   0.0             989.1
# 3                  27.2                       94.0   0.0             978.8
# 4                  22.9                        NaN   NaN             982.4
#
#    bike_stands  available_bike_stands
# 0           22                     13
# 1           22                      0
# 2           22                      8
# 3           22                     14
# 4           22                     21

# %% [markdown]
# Sortiranje zapisov glede na čas zapisa

# %%
df['date'] = pd.to_datetime(df['date'])

df.sort_values(by=['date'], inplace=True)
df.head()
# Out:
#                            date  temperature  relative_humidity  dew_point  \
# 11830 2023-06-25 19:07:30+00:00         24.2                 43       10.9
# 5971  2023-06-25 19:33:48+00:00         21.5                 55       12.1
# 23274 2023-06-25 19:45:44+00:00         21.5                 55       12.1
# 9286  2023-06-25 19:55:29+00:00         21.5                 55       12.1
# 22190 2023-06-25 20:02:16+00:00         21.5                 55       12.1
#
#        apparent_temperature  precipitation_probability  rain  \
# 11830                  23.3                        0.0   0.0
# 5971                   21.7                        0.0   0.0
# 23274                  21.7                        0.0   0.0
# 9286                   21.7                        0.0   NaN
# 22190                  21.7                        NaN   0.0
#
#        surface_pressure  bike_stands  available_bike_stands
# 11830             984.5           22                      8
# 5971              984.4           22                      7
# 23274             984.4           22                      6
# 9286              984.4           22                      8
# 22190             984.4           22                     12

# %% [markdown]
# Izris grafa vrednosti izposoje koles glede na čas

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['date'], df['available_bike_stands'])
plt.xlabel('Time')
plt.ylabel('Available bike stands')
plt.title('Available bike stands vs. Time')
plt.show()

# %%
bike_stands = df['available_bike_stands']
bike_stands_array = bike_stands.values.reshape(-1, 1)

# %%
test_data_size = 1488

train_data, test_data = bike_stands_array[:-test_data_size],bike_stands_array[-test_data_size:]

# %%
scaler = MinMaxScaler()

train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

# %%
def sliding_window(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        window = data[i:(i + window_size)]
        target = data[i + window_size]
        X.append(window)
        y.append(target)
    return np.array(X), np.array(y)

# %%
window_size = 186
X_train, y_train = sliding_window(train_data, window_size)
X_test, y_test = sliding_window(test_data, window_size)

# %%
print(X_test.shape)
# Out:
# (1302, 1, 186)

# %%
# Preoblikovanje vhodnih učnih podatkov
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# Preverjanje oblik
print(f"Oblika učnih podatkov: X_train: {X_train.shape}, y_train: {y_train.shape}")
print(f"Oblika testnih podatkov: X_test: {X_test.shape}, y_test: {y_test.shape}")
# Out:
# Oblika učnih podatkov: X_train: (25995, 1, 186), y_train: (25995, 1)
# Oblika testnih podatkov: X_test: (1302, 1, 186), y_test: (1302, 1)

# %%
model_rnn = Sequential([
    SimpleRNN(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    SimpleRNN(32),
    Dense(16, activation='relu'),
    Dense(1)
], name="RNN")

model_gru = Sequential([
    GRU(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    GRU(32),
    Dense(16, activation='relu'),
    Dense(1)
], name="GRU")

model_lstm = Sequential([
    LSTM(32, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    LSTM(32),
    Dense(16, activation='relu'),
    Dense(1)
], name="LSTM")

# %%
models = [model_rnn, model_gru, model_lstm]
history = {}

# %%
for model in models:
    model.compile(optimizer='adam', loss='mean_squared_error')
    h = model.fit(X_train, y_train, epochs=50, batch_size=64, verbose=2)
    history[model.name] = h.history
# Out:
# Epoch 1/50
# 2023-12-13 23:17:46.021002: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 407/407 - 1s - loss: 0.0172 - 1s/epoch - 3ms/step
# Epoch 2/50
# 407/407 - 0s - loss: 0.0073 - 403ms/epoch - 990us/step
# Epoch 3/50
# 407/407 - 0s - loss: 0.0062 - 356ms/epoch - 874us/step
# Epoch 4/50
# 407/407 - 1s - loss: 0.0055 - 656ms/epoch - 2ms/step
# Epoch 5/50
# 407/407 - 0s - loss: 0.0053 - 377ms/epoch - 927us/step
# Epoch 6/50
# 407/407 - 0s - loss: 0.0052 - 371ms/epoch - 912us/step
# Epoch 7/50
# 407/407 - 0s - loss: 0.0048 - 317ms/epoch - 779us/step
# Epoch 8/50
# 407/407 - 0s - loss: 0.0048 - 298ms/epoch - 732us/step
# Epoch 9/50
# 407/407 - 0s - loss: 0.0047 - 318ms/epoch - 781us/step
# Epoch 10/50
# 407/407 - 0s - loss: 0.0048 - 299ms/epoch - 734us/step
# Epoch 11/50
# 407/407 - 0s - loss: 0.0045 - 297ms/epoch - 729us/step
# Epoch 12/50
# 407/407 - 0s - loss: 0.0043 - 300ms/epoch - 738us/step
# Epoch 13/50
# 407/407 - 0s - loss: 0.0046 - 341ms/epoch - 838us/step
# Epoch 14/50
# 407/407 - 0s - loss: 0.0044 - 371ms/epoch - 911us/step
# Epoch 15/50
# 407/407 - 0s - loss: 0.0044 - 421ms/epoch - 1ms/step
# Epoch 16/50
# 407/407 - 0s - loss: 0.0043 - 442ms/epoch - 1ms/step
# Epoch 17/50
# 407/407 - 1s - loss: 0.0043 - 534ms/epoch - 1ms/step
# Epoch 18/50
# 407/407 - 1s - loss: 0.0042 - 571ms/epoch - 1ms/step
# Epoch 19/50
# 407/407 - 0s - loss: 0.0043 - 408ms/epoch - 1ms/step
# Epoch 20/50
# 407/407 - 0s - loss: 0.0043 - 370ms/epoch - 908us/step
# Epoch 21/50
# 407/407 - 0s - loss: 0.0043 - 380ms/epoch - 934us/step
# Epoch 22/50
# 407/407 - 0s - loss: 0.0042 - 318ms/epoch - 782us/step
# Epoch 23/50
# 407/407 - 0s - loss: 0.0042 - 290ms/epoch - 712us/step
# Epoch 24/50
# 407/407 - 0s - loss: 0.0041 - 302ms/epoch - 743us/step
# Epoch 25/50
# 407/407 - 0s - loss: 0.0042 - 285ms/epoch - 700us/step
# Epoch 26/50
# 407/407 - 0s - loss: 0.0042 - 282ms/epoch - 692us/step
# Epoch 27/50
# 407/407 - 0s - loss: 0.0041 - 346ms/epoch - 850us/step
# Epoch 28/50
# 407/407 - 0s - loss: 0.0040 - 330ms/epoch - 810us/step
# Epoch 29/50
# 407/407 - 0s - loss: 0.0041 - 354ms/epoch - 869us/step
# Epoch 30/50
# 407/407 - 0s - loss: 0.0043 - 347ms/epoch - 853us/step
# Epoch 31/50
# 407/407 - 0s - loss: 0.0041 - 286ms/epoch - 704us/step
# Epoch 32/50
# 407/407 - 0s - loss: 0.0041 - 315ms/epoch - 774us/step
# Epoch 33/50
# 407/407 - 0s - loss: 0.0041 - 304ms/epoch - 746us/step
# Epoch 34/50
# 407/407 - 0s - loss: 0.0041 - 324ms/epoch - 797us/step
# Epoch 35/50
# 407/407 - 0s - loss: 0.0040 - 288ms/epoch - 708us/step
# Epoch 36/50
# 407/407 - 0s - loss: 0.0041 - 278ms/epoch - 683us/step
# Epoch 37/50
# 407/407 - 0s - loss: 0.0040 - 296ms/epoch - 727us/step
# Epoch 38/50
# 407/407 - 0s - loss: 0.0041 - 281ms/epoch - 691us/step
# Epoch 39/50
# 407/407 - 0s - loss: 0.0041 - 294ms/epoch - 722us/step
# Epoch 40/50
# 407/407 - 0s - loss: 0.0040 - 287ms/epoch - 706us/step
# Epoch 41/50
# 407/407 - 0s - loss: 0.0041 - 283ms/epoch - 695us/step
# Epoch 42/50
# 407/407 - 0s - loss: 0.0039 - 297ms/epoch - 730us/step
# Epoch 43/50
# 407/407 - 0s - loss: 0.0040 - 304ms/epoch - 746us/step
# Epoch 44/50
# 407/407 - 0s - loss: 0.0041 - 307ms/epoch - 753us/step
# Epoch 45/50
# 407/407 - 0s - loss: 0.0040 - 297ms/epoch - 730us/step
# Epoch 46/50
# 407/407 - 0s - loss: 0.0039 - 295ms/epoch - 724us/step
# Epoch 47/50
# 407/407 - 0s - loss: 0.0040 - 303ms/epoch - 744us/step
# Epoch 48/50
# 407/407 - 0s - loss: 0.0039 - 285ms/epoch - 700us/step
# Epoch 49/50
# 407/407 - 0s - loss: 0.0040 - 300ms/epoch - 738us/step
# Epoch 50/50
# 407/407 - 0s - loss: 0.0040 - 295ms/epoch - 725us/step
# Epoch 1/50
# 407/407 - 2s - loss: 0.0246 - 2s/epoch - 5ms/step
# Epoch 2/50
# 407/407 - 1s - loss: 0.0067 - 561ms/epoch - 1ms/step
# Epoch 3/50
# 407/407 - 1s - loss: 0.0056 - 548ms/epoch - 1ms/step
# Epoch 4/50
# 407/407 - 1s - loss: 0.0051 - 523ms/epoch - 1ms/step
# Epoch 5/50
# 407/407 - 1s - loss: 0.0047 - 553ms/epoch - 1ms/step
# Epoch 6/50
# 407/407 - 1s - loss: 0.0048 - 555ms/epoch - 1ms/step
# Epoch 7/50
# 407/407 - 1s - loss: 0.0046 - 580ms/epoch - 1ms/step
# Epoch 8/50
# 407/407 - 1s - loss: 0.0044 - 573ms/epoch - 1ms/step
# Epoch 9/50
# 407/407 - 1s - loss: 0.0043 - 557ms/epoch - 1ms/step
# Epoch 10/50
# 407/407 - 1s - loss: 0.0046 - 562ms/epoch - 1ms/step
# Epoch 11/50
# 407/407 - 1s - loss: 0.0043 - 584ms/epoch - 1ms/step
# Epoch 12/50
# 407/407 - 1s - loss: 0.0042 - 567ms/epoch - 1ms/step
# Epoch 13/50
# 407/407 - 1s - loss: 0.0042 - 642ms/epoch - 2ms/step
# Epoch 14/50
# 407/407 - 1s - loss: 0.0042 - 574ms/epoch - 1ms/step
# Epoch 15/50
# 407/407 - 1s - loss: 0.0041 - 588ms/epoch - 1ms/step
# Epoch 16/50
# 407/407 - 1s - loss: 0.0042 - 557ms/epoch - 1ms/step
# Epoch 17/50
# 407/407 - 1s - loss: 0.0041 - 566ms/epoch - 1ms/step
# Epoch 18/50
# 407/407 - 1s - loss: 0.0041 - 551ms/epoch - 1ms/step
# Epoch 19/50
# 407/407 - 1s - loss: 0.0040 - 702ms/epoch - 2ms/step
# Epoch 20/50
# 407/407 - 1s - loss: 0.0042 - 1s/epoch - 3ms/step
# Epoch 21/50
# 407/407 - 1s - loss: 0.0041 - 844ms/epoch - 2ms/step
# Epoch 22/50
# 407/407 - 1s - loss: 0.0042 - 715ms/epoch - 2ms/step
# Epoch 23/50
# 407/407 - 1s - loss: 0.0040 - 737ms/epoch - 2ms/step
# Epoch 24/50
# 407/407 - 1s - loss: 0.0041 - 665ms/epoch - 2ms/step
# Epoch 25/50
# 407/407 - 1s - loss: 0.0040 - 735ms/epoch - 2ms/step
# Epoch 26/50
# 407/407 - 1s - loss: 0.0041 - 655ms/epoch - 2ms/step
# Epoch 27/50
# 407/407 - 1s - loss: 0.0040 - 624ms/epoch - 2ms/step
# Epoch 28/50
# 407/407 - 1s - loss: 0.0040 - 601ms/epoch - 1ms/step
# Epoch 29/50
# 407/407 - 1s - loss: 0.0040 - 592ms/epoch - 1ms/step
# Epoch 30/50
# 407/407 - 1s - loss: 0.0039 - 644ms/epoch - 2ms/step
# Epoch 31/50
# 407/407 - 1s - loss: 0.0041 - 578ms/epoch - 1ms/step
# Epoch 32/50
# 407/407 - 1s - loss: 0.0041 - 571ms/epoch - 1ms/step
# Epoch 33/50
# 407/407 - 1s - loss: 0.0039 - 565ms/epoch - 1ms/step
# Epoch 34/50
# 407/407 - 1s - loss: 0.0039 - 549ms/epoch - 1ms/step
# Epoch 35/50
# 407/407 - 1s - loss: 0.0039 - 611ms/epoch - 2ms/step
# Epoch 36/50
# 407/407 - 1s - loss: 0.0039 - 542ms/epoch - 1ms/step
# Epoch 37/50
# 407/407 - 1s - loss: 0.0039 - 558ms/epoch - 1ms/step
# Epoch 38/50
# 407/407 - 1s - loss: 0.0039 - 572ms/epoch - 1ms/step
# Epoch 39/50
# 407/407 - 1s - loss: 0.0041 - 514ms/epoch - 1ms/step
# Epoch 40/50
# 407/407 - 1s - loss: 0.0039 - 523ms/epoch - 1ms/step
# Epoch 41/50
# 407/407 - 1s - loss: 0.0038 - 509ms/epoch - 1ms/step
# Epoch 42/50
# 407/407 - 1s - loss: 0.0039 - 548ms/epoch - 1ms/step
# Epoch 43/50
# 407/407 - 1s - loss: 0.0039 - 512ms/epoch - 1ms/step
# Epoch 44/50
# 407/407 - 1s - loss: 0.0039 - 540ms/epoch - 1ms/step
# Epoch 45/50
# 407/407 - 1s - loss: 0.0038 - 523ms/epoch - 1ms/step
# Epoch 46/50
# 407/407 - 1s - loss: 0.0038 - 512ms/epoch - 1ms/step
# Epoch 47/50
# 407/407 - 1s - loss: 0.0039 - 533ms/epoch - 1ms/step
# Epoch 48/50
# 407/407 - 1s - loss: 0.0038 - 509ms/epoch - 1ms/step
# Epoch 49/50
# 407/407 - 1s - loss: 0.0039 - 504ms/epoch - 1ms/step
# Epoch 50/50
# 407/407 - 1s - loss: 0.0038 - 542ms/epoch - 1ms/step
# Epoch 1/50
# 407/407 - 2s - loss: 0.0377 - 2s/epoch - 4ms/step
# Epoch 2/50
# 407/407 - 0s - loss: 0.0073 - 493ms/epoch - 1ms/step
# Epoch 3/50
# 407/407 - 0s - loss: 0.0057 - 496ms/epoch - 1ms/step
# Epoch 4/50
# 407/407 - 0s - loss: 0.0052 - 492ms/epoch - 1ms/step
# Epoch 5/50
# 407/407 - 0s - loss: 0.0049 - 491ms/epoch - 1ms/step
# Epoch 6/50
# 407/407 - 1s - loss: 0.0046 - 527ms/epoch - 1ms/step
# Epoch 7/50
# 407/407 - 0s - loss: 0.0046 - 499ms/epoch - 1ms/step
# Epoch 8/50
# 407/407 - 0s - loss: 0.0045 - 497ms/epoch - 1ms/step
# Epoch 9/50
# 407/407 - 0s - loss: 0.0042 - 487ms/epoch - 1ms/step
# Epoch 10/50
# 407/407 - 0s - loss: 0.0043 - 500ms/epoch - 1ms/step
# Epoch 11/50
# 407/407 - 1s - loss: 0.0042 - 516ms/epoch - 1ms/step
# Epoch 12/50
# 407/407 - 1s - loss: 0.0042 - 521ms/epoch - 1ms/step
# Epoch 13/50
# 407/407 - 1s - loss: 0.0042 - 546ms/epoch - 1ms/step
# Epoch 14/50
# 407/407 - 1s - loss: 0.0042 - 568ms/epoch - 1ms/step
# Epoch 15/50
# 407/407 - 1s - loss: 0.0043 - 626ms/epoch - 2ms/step
# Epoch 16/50
# 407/407 - 1s - loss: 0.0041 - 511ms/epoch - 1ms/step
# Epoch 17/50
# 407/407 - 1s - loss: 0.0040 - 540ms/epoch - 1ms/step
# Epoch 18/50
# 407/407 - 1s - loss: 0.0041 - 512ms/epoch - 1ms/step
# Epoch 19/50
# 407/407 - 1s - loss: 0.0040 - 516ms/epoch - 1ms/step
# Epoch 20/50
# 407/407 - 1s - loss: 0.0041 - 515ms/epoch - 1ms/step
# Epoch 21/50
# 407/407 - 1s - loss: 0.0041 - 558ms/epoch - 1ms/step
# Epoch 22/50
# 407/407 - 1s - loss: 0.0041 - 504ms/epoch - 1ms/step
# Epoch 23/50
# 407/407 - 1s - loss: 0.0040 - 523ms/epoch - 1ms/step
# Epoch 24/50
# 407/407 - 1s - loss: 0.0042 - 508ms/epoch - 1ms/step
# Epoch 25/50
# 407/407 - 1s - loss: 0.0039 - 553ms/epoch - 1ms/step
# Epoch 26/50
# 407/407 - 1s - loss: 0.0040 - 514ms/epoch - 1ms/step
# Epoch 27/50
# 407/407 - 0s - loss: 0.0042 - 498ms/epoch - 1ms/step
# Epoch 28/50
# 407/407 - 1s - loss: 0.0040 - 500ms/epoch - 1ms/step
# Epoch 29/50
# 407/407 - 1s - loss: 0.0040 - 501ms/epoch - 1ms/step
# Epoch 30/50
# 407/407 - 0s - loss: 0.0040 - 496ms/epoch - 1ms/step
# Epoch 31/50
# 407/407 - 1s - loss: 0.0039 - 550ms/epoch - 1ms/step
# Epoch 32/50
# 407/407 - 1s - loss: 0.0040 - 504ms/epoch - 1ms/step
# Epoch 33/50
# 407/407 - 1s - loss: 0.0039 - 516ms/epoch - 1ms/step
# Epoch 34/50
# 407/407 - 1s - loss: 0.0039 - 513ms/epoch - 1ms/step
# Epoch 35/50
# 407/407 - 0s - loss: 0.0039 - 495ms/epoch - 1ms/step
# Epoch 36/50
# 407/407 - 1s - loss: 0.0040 - 504ms/epoch - 1ms/step
# Epoch 37/50
# 407/407 - 1s - loss: 0.0040 - 502ms/epoch - 1ms/step
# Epoch 38/50
# 407/407 - 0s - loss: 0.0039 - 499ms/epoch - 1ms/step
# Epoch 39/50
# 407/407 - 1s - loss: 0.0039 - 578ms/epoch - 1ms/step
# Epoch 40/50
# 407/407 - 0s - loss: 0.0039 - 497ms/epoch - 1ms/step
# Epoch 41/50
# 407/407 - 1s - loss: 0.0039 - 504ms/epoch - 1ms/step
# Epoch 42/50
# 407/407 - 1s - loss: 0.0039 - 504ms/epoch - 1ms/step
# Epoch 43/50
# 407/407 - 1s - loss: 0.0040 - 507ms/epoch - 1ms/step
# Epoch 44/50
# 407/407 - 1s - loss: 0.0038 - 604ms/epoch - 1ms/step
# Epoch 45/50
# 407/407 - 1s - loss: 0.0038 - 588ms/epoch - 1ms/step
# Epoch 46/50
# 407/407 - 1s - loss: 0.0039 - 530ms/epoch - 1ms/step
# Epoch 47/50
# 407/407 - 1s - loss: 0.0039 - 520ms/epoch - 1ms/step
# Epoch 48/50
# 407/407 - 1s - loss: 0.0039 - 519ms/epoch - 1ms/step
# Epoch 49/50
# 407/407 - 1s - loss: 0.0038 - 528ms/epoch - 1ms/step
# Epoch 50/50
# 407/407 - 1s - loss: 0.0039 - 560ms/epoch - 1ms/step

# %%
plt.figure(figsize=(12, 8))
for name, values in history.items():
    plt.plot(values['loss'], label=name)

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Function vs. Epochs for RNN, GRU, LSTM Models')
plt.legend()
plt.show()

# %%
import pickle


with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
    
model_gru.save('model_gru.h5')

# %%
df.head(186)
# Out:
#                            date  temperature  relative_humidity  dew_point  \
# 11830 2023-06-25 19:07:30+00:00         24.2                 43       10.9
# 5971  2023-06-25 19:33:48+00:00         21.5                 55       12.1
# 23274 2023-06-25 19:45:44+00:00         21.5                 55       12.1
# 9286  2023-06-25 19:55:29+00:00         21.5                 55       12.1
# 22190 2023-06-25 20:02:16+00:00         21.5                 55       12.1
# ...                         ...          ...                ...        ...
# 1573  2023-06-27 05:12:44+00:00         19.0                 81       15.6
# 24617 2023-06-27 05:24:18+00:00         19.0                 81       15.6
# 1746  2023-06-27 05:27:46+00:00         19.0                 81       15.6
# 23755 2023-06-27 05:34:19+00:00         20.7                 83       17.7
# 2244  2023-06-27 05:43:13+00:00         20.7                 83       17.7
#
#        apparent_temperature  precipitation_probability  rain  \
# 11830                  23.3                        0.0   0.0
# 5971                   21.7                        0.0   0.0
# 23274                  21.7                        0.0   0.0
# 9286                   21.7                        0.0   NaN
# 22190                  21.7                        NaN   0.0
# ...                     ...                        ...   ...
# 1573                   19.9                       41.0   0.0
# 24617                  19.9                       41.0   0.0
# 1746                   19.9                       41.0   0.0
# 23755                  22.7                       65.0   0.0
# 2244                   22.7                       65.0   0.0
#
#        surface_pressure  bike_stands  available_bike_stands
# 11830             984.5           22                      8
# 5971              984.4           22                      7
# 23274             984.4           22                      6
# 9286              984.4           22                      8
# 22190             984.4           22                     12
# ...                 ...          ...                    ...
# 1573              982.1           22                     11
# 24617             982.1           22                     15
# 1746              982.1           22                     17
# 23755             982.5           22                     22
# 2244              982.5           22                     22
#
# [186 rows x 10 columns]

# %%
results = {
    'MSE': [],
    'MAE': [],
    'EVS': []
}

y_test = scaler.inverse_transform(y_test)

for model in models:
    predicted = model.predict(X_test, verbose=0)
    predicted = scaler.inverse_transform(predicted)

    mse = mean_squared_error(y_test, predicted)
    mae = mean_absolute_error(y_test, predicted)
    evs = explained_variance_score(y_test, predicted)
    print(f'{model.name} - MSE: {mse:.2f}')
    print(f'{model.name} - MAE: {mae:.2f}')
    print(f'{model.name} - EVS: {evs:.2f}')
    print("-" * 20)
    results['MSE'].append((model.name, mse))
    results['MAE'].append((model.name, mae))
    results['EVS'].append((model.name, evs))
# Out:
# [[[0.86363636 1.         1.         ... 0.5        0.54545455 0.54545455]]
#
#  [[1.         1.         1.         ... 0.54545455 0.54545455 0.54545455]]
#
#  [[1.         1.         1.         ... 0.54545455 0.54545455 0.54545455]]
#
#  ...
#
#  [[0.27272727 0.27272727 0.31818182 ... 0.         0.         0.        ]]
#
#  [[0.27272727 0.31818182 0.13636364 ... 0.         0.         0.        ]]
#
#  [[0.31818182 0.13636364 0.18181818 ... 0.         0.         0.        ]]]
# RNN - MSE: 2.80
# RNN - MAE: 1.24
# RNN - EVS: 0.95
# --------------------
# GRU - MSE: 2.65
# GRU - MAE: 1.19
# GRU - EVS: 0.95
# --------------------
# LSTM - MSE: 2.65
# LSTM - MAE: 1.18
# LSTM - EVS: 0.95
# --------------------

# %%
metrics = ['MSE', 'MAE', 'EVS']
model_names = [model.name for model in models]

width = 0.8
cols = len(metrics)

fig, axs = plt.subplots(1, cols, figsize=(12, 4))

for i, metric in enumerate(metrics):
    ax = axs[i]
    max = -float('inf')


    for j, model in enumerate(model_names):
        value = results[metric][j][1]
        if value > max:
          max = value
        ax.bar(j, value, width, label=model)
        ax.text(j, value, str(round(value, 3)), ha='center', va='bottom')


    ax.set_ylim([0, max * 1.09])
    ax.set_title(f'{metric}')
    ax.set_xticks([], [])
    ax.legend(loc='lower left')

plt.show()

# %%
dates = df['date'].values
print(dates)
# Out:
# ['2023-06-25T19:07:30.000000000' '2023-06-25T19:33:48.000000000'
#  '2023-06-25T19:45:44.000000000' ... '2023-11-12T23:34:21.000000000'
#  '2023-11-12T23:44:27.000000000' '2023-11-12T23:54:32.000000000']

# %%
inverse_y_test = scaler.inverse_transform(y_test)
predictions = {}

for model in models:
    predicted = model.predict(X_test, verbose=0)
    predicted = scaler.inverse_transform(predicted)
    predictions[model.name] = predicted

# %%
output_dataframes = {}

for model in models:
    data = {
        'date': dates[-test_data_size + window_size:],
        'true': y_test.reshape(-1),
        'predicted': predictions[model.name].reshape(-1)
    }
    output_dataframes[model.name] = pd.DataFrame(data)

# %%
output_dataframes['RNN'].head()
# Out:
#                  date  true  predicted
# 0 2023-11-07 05:49:07  12.0  12.893146
# 1 2023-11-07 05:52:30  12.0  12.461379
# 2 2023-11-07 05:58:13  14.0  12.536840
# 3 2023-11-07 06:02:42  16.0  14.097146
# 4 2023-11-07 06:08:58  17.0  16.041504

# %%
for model in models:
    output_df=output_dataframes[model.name]
    model_name = model.name
    plt.figure(figsize=(12, 8))
    plt.plot(output_df['date'], output_df['true'], label='True')
    plt.plot(output_df['date'],output_df['predicted'], label=model_name)
    plt.xlabel('Time')
    plt.ylabel('Available bike stands')
    plt.title('Available bike stands vs. Time')
    plt.legend()
    plt.show()

# %%
for model in models:
    model_df = output_dataframes[model.name]
    model_name = model.name
    plt.figure(figsize=(12, 6))
    plt.plot(df['date'].iloc[:-test_data_size], df['available_bike_stands'].iloc[:-test_data_size], label='Train')
    plt.plot(model_df['date'], model_df['predicted'], label=model_name, color='green')
    plt.plot(df['date'].iloc[-test_data_size:], df['available_bike_stands'].iloc[-test_data_size:], label='Test')
    plt.xlabel('Time')
    plt.ylabel('Available bike stands')
    plt.title('Available bike stands vs. Time')
    plt.legend()
    plt.show()

# %%
df_bonus = pd.read_csv('data/mbajk.csv')
df_bonus.head()
# Out:
#                         date  temperature  relative_humidity  dew_point  \
# 0  2023-07-30 12:12:58+00:00         24.1                 69       18.1
# 1  2023-09-11 20:14:06+00:00         19.2                 85       16.6
# 2  2023-07-09 05:12:32+00:00          NaN                 92       16.2
# 3  2023-07-21 12:37:13+00:00          NaN                 64       17.2
# 4  2023-07-03 17:01:20+00:00          NaN                 80       17.3
#
#    apparent_temperature  precipitation_probability  rain  surface_pressure  \
# 0                  27.5                       27.0   0.0             981.3
# 1                  20.9                        0.0   0.0             981.7
# 2                  19.2                        0.0   0.0             989.1
# 3                  27.2                       94.0   0.0             978.8
# 4                  22.9                        NaN   NaN             982.4
#
#    bike_stands  available_bike_stands
# 0           22                     13
# 1           22                      0
# 2           22                      8
# 3           22                     14
# 4           22                     21

# %%
df_bonus['date'] = pd.to_datetime(df_bonus['date'])
df_bonus.sort_values(by=['date'], inplace=True)

# %%
selected_features = ['available_bike_stands', 'apparent_temperature', 'dew_point', 'precipitation_probability', 'surface_pressure']

data = df_bonus[selected_features]
data.head()
# Out:
#        available_bike_stands  apparent_temperature  dew_point  \
# 11830                      8                  23.3       10.9
# 5971                       7                  21.7       12.1
# 23274                      6                  21.7       12.1
# 9286                       8                  21.7       12.1
# 22190                     12                  21.7       12.1
#
#        precipitation_probability  surface_pressure
# 11830                        0.0             984.5
# 5971                         0.0             984.4
# 23274                        0.0             984.4
# 9286                         0.0             984.4
# 22190                        NaN             984.4

# %%
from sklearn.ensemble import RandomForestRegressor

columns_with_missing = data.columns[data.isnull().any()].tolist()
for col in columns_with_missing:
    missing_indices = data[col].isnull()
    # Create features (X) and target variable (y)
    X = data.drop(columns=columns_with_missing)
    y = data[col]
    
    # Split into training and test sets
    X_train = X[~missing_indices]
    y_train = y[~missing_indices]
    X_test = X[missing_indices]
    
    # Initialize and train Random Forest Regressor
    rf = RandomForestRegressor()
    rf.fit(X_train, y_train)
    
    # Predict missing values
    predicted_values = rf.predict(X_test)
    
    # Fill in missing values in the original DataFrame
    data.loc[missing_indices, col] = predicted_values

# %%
time_series = data.values

# %%
test_data_size = 1488
train_data, test_data = time_series[:-test_data_size], time_series[-test_data_size:]

# %%
scaler = MinMaxScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.transform(test_data)

# %%
def sliding_window_multi(data, window_size):
    X, y = [], []
    for i in range(len(data) - window_size):
        window = data[i:(i + window_size), :]
        target = data[i + window_size, 0]  # considering only 'available_bike_stands' as the target
        X.append(window)
        y.append(target)
    return np.array(X), np.array(y)

# %%
window_size = 186

# Generating train-test data with sliding window function
X_train_multi, y_train_multi = sliding_window_multi(train_data, window_size)
X_test_multi, y_test_multi = sliding_window_multi(test_data, window_size)

# Reshaping for RNN model
X_train_multi = X_train_multi.reshape(X_train_multi.shape[0], X_train_multi.shape[1], X_train_multi.shape[2])
X_test_multi = X_test_multi.reshape(X_test_multi.shape[0], X_test_multi.shape[1], X_test_multi.shape[2])

# Verifying shapes
print(f"Shape of training data: X_train: {X_train_multi.shape}, y_train: {y_train_multi.shape}")
print(f"Shape of testing data: X_test: {X_test_multi.shape}, y_test: {y_test_multi.shape}")
# Out:
# Shape of training data: X_train: (25995, 186, 5), y_train: (25995,)
# Shape of testing data: X_test: (1302, 186, 5), y_test: (1302,)

# %%
model_rnn_multi = Sequential([
    SimpleRNN(32, return_sequences=True, input_shape=(X_train_multi.shape[1], X_train_multi.shape[2])),
    SimpleRNN(32),
    Dense(16, activation='relu'),
    Dense(1)
], name="RNN")

model_gru_multi = Sequential([
    GRU(32, return_sequences=True, input_shape=(X_train_multi.shape[1], X_train_multi.shape[2])),
    GRU(32),
    Dense(16, activation='relu'),
    Dense(1)
], name="GRU")

model_lstm_multi = Sequential([
    LSTM(32, return_sequences=True, input_shape=(X_train_multi.shape[1], X_train_multi.shape[2])),
    LSTM(32),
    Dense(16, activation='relu'),
    Dense(1)
], name="LSTM")

# %%
models_multi = [model_rnn_multi, model_gru_multi, model_lstm_multi]
history_multi = {}

# %%
print(np.any(np.isnan(X_train_multi)))
print(np.any(np.isnan(y_train_multi)))
print(np.any(np.isinf(X_train_multi)))
print(np.any(np.isinf(y_train_multi)))
# Out:
# False
# False
# False
# False

# %%
for model in models_multi:
    model.compile(optimizer='adam', loss='mean_squared_error')
    history = model.fit(X_train_multi, y_train_multi, epochs=50, batch_size=64, verbose=1, validation_data=(X_test_multi, y_test_multi))
    history_multi[model.name] = history.history
# Out:
# Epoch 1/50
# 407/407 [==============================] - 14s 33ms/step - loss: 0.0075 - val_loss: 0.0060
# Epoch 2/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0042 - val_loss: 0.0061
# Epoch 3/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 4/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0041 - val_loss: 0.0059
# Epoch 5/50
# 407/407 [==============================] - 14s 34ms/step - loss: 0.0041 - val_loss: 0.0058
# Epoch 6/50
# 407/407 [==============================] - 13s 33ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 7/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 8/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 9/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0040 - val_loss: 0.0059
# Epoch 10/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0040 - val_loss: 0.0062
# Epoch 11/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 12/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 13/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0040 - val_loss: 0.0061
# Epoch 14/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0040 - val_loss: 0.0059
# Epoch 15/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 16/50
# 407/407 [==============================] - 14s 33ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 17/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 18/50
# 407/407 [==============================] - 13s 33ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 19/50
# 407/407 [==============================] - 13s 33ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 20/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 21/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 22/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 23/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0061
# Epoch 24/50
# 407/407 [==============================] - 13s 33ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 25/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 26/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 27/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 28/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 29/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 30/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 31/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 32/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 33/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 34/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 35/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0039 - val_loss: 0.0060
# Epoch 36/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 37/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 38/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 39/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 40/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0059
# Epoch 41/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 42/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 43/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 44/50
# 407/407 [==============================] - 13s 33ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 45/50
# 407/407 [==============================] - 13s 33ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 46/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 47/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 48/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0061
# Epoch 49/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 50/50
# 407/407 [==============================] - 13s 32ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 1/50
# 407/407 [==============================] - 36s 84ms/step - loss: 0.0119 - val_loss: 0.0062
# Epoch 2/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0042 - val_loss: 0.0056
# Epoch 3/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0040 - val_loss: 0.0058
# Epoch 4/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0040 - val_loss: 0.0056
# Epoch 5/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 6/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0040 - val_loss: 0.0071
# Epoch 7/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0040 - val_loss: 0.0056
# Epoch 8/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0040 - val_loss: 0.0060
# Epoch 9/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0040 - val_loss: 0.0059
# Epoch 10/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 11/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 12/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0039 - val_loss: 0.0057
# Epoch 13/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 14/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0040 - val_loss: 0.0056
# Epoch 15/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 16/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 17/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 18/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 19/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 20/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0038 - val_loss: 0.0059
# Epoch 21/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0059
# Epoch 22/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 23/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 24/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 25/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0038 - val_loss: 0.0059
# Epoch 26/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 27/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 28/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0060
# Epoch 29/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 30/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 31/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 32/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 33/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 34/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 35/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0037 - val_loss: 0.0054
# Epoch 36/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 37/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 38/50
# 407/407 [==============================] - 35s 86ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 39/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 40/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 41/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 42/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 43/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0037 - val_loss: 0.0054
# Epoch 44/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 45/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0037 - val_loss: 0.0055
# Epoch 46/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0037 - val_loss: 0.0057
# Epoch 47/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 48/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 49/50
# 407/407 [==============================] - 35s 85ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 50/50
# 407/407 [==============================] - 34s 85ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 1/50
# 407/407 [==============================] - 35s 83ms/step - loss: 0.0180 - val_loss: 0.0108
# Epoch 2/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 3/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0043 - val_loss: 0.0059
# Epoch 4/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0041 - val_loss: 0.0057
# Epoch 5/50
# 407/407 [==============================] - 34s 82ms/step - loss: 0.0040 - val_loss: 0.0058
# Epoch 6/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 7/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0040 - val_loss: 0.0060
# Epoch 8/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 9/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 10/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0040 - val_loss: 0.0057
# Epoch 11/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 12/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0039 - val_loss: 0.0055
# Epoch 13/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0039 - val_loss: 0.0059
# Epoch 14/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 15/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 16/50
# 407/407 [==============================] - 34s 82ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 17/50
# 407/407 [==============================] - 33s 81ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 18/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 19/50
# 407/407 [==============================] - 33s 81ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 20/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 21/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 22/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 23/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 24/50
# 407/407 [==============================] - 34s 82ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 25/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 26/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 27/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 28/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 29/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 30/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 31/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 32/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 33/50
# 407/407 [==============================] - 34s 82ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 34/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 35/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0061
# Epoch 36/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 37/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 38/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 39/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 40/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 41/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 42/50
# 407/407 [==============================] - 34s 84ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 43/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 44/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 45/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0038 - val_loss: 0.0055
# Epoch 46/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 47/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0037 - val_loss: 0.0056
# Epoch 48/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 49/50
# 407/407 [==============================] - 33s 82ms/step - loss: 0.0037 - val_loss: 0.0058
# Epoch 50/50
# 407/407 [==============================] - 34s 83ms/step - loss: 0.0037 - val_loss: 0.0054

# %%
plt.figure(figsize=(12, 8))
for name, values in history_multi.items():
    plt.plot(values['loss'], label=name)

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Function vs. Epochs for RNN, GRU, LSTM Models')
plt.legend()
plt.show()

# %%
results_multi = {
    'MSE': [],
    'MAE': [],
    'EVS': []
}

# %%
X_train_multi_reshaped = np.swapaxes(X_train_multi, 1, 2)
X_test_multi_reshaped = np.swapaxes(X_test_multi, 1, 2)

# Shapes after reshaping
print(f"Preoblikovani X_train: {X_train_multi_reshaped.shape}")
print(f"Preoblikovani X_test: {X_test_multi_reshaped.shape}")
# Out:
# Preoblikovani X_train: (25995, 5, 186)
# Preoblikovani X_test: (1302, 5, 186)

# %%
# vsaka značilnica svoj skaler
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 y_test_multi = scaler.inverse_transform(y_test_multi)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/rnn/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:543, in MinMaxScaler.inverse_transform(self, X)
#     529 """Undo the scaling of X according to feature_range.
#     530
#     531 Parameters
#    (...)
#     539     Transformed data.
#     540 """
#     541 check_is_fitted(self)
# --> 543 X = check_array(
#     544     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     545 )
#     547 X -= self.min_
#     548 X /= self.scale_
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/rnn/lib/python3.10/site-packages/sklearn/utils/validation.py:940, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     938     # If input is 1D raise error
#     939     if array.ndim == 1:
# --> 940         raise ValueError(
#     941             "Expected 2D array, got 1D array instead:\narray={}.\n"
#     942             "Reshape your data either using array.reshape(-1, 1) if "
#     943             "your data has a single feature or array.reshape(1, -1) "
#     944             "if it contains a single sample.".format(array)
#     945         )
#     947 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#     948     raise ValueError(
#     949         "dtype='numeric' is not compatible with arrays of bytes/strings."
#     950         "Convert your data to numeric values explicitly instead."
#     951     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.54545455 0.54545455 0.63636364 ... 0.         0.         0.        ].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
